# %%
from pycaret.datasets import get_data

# %%
verbose = True
dataset = 'credit'
save_copy = False
load_dataset = get_data(dataset = dataset, save_copy=save_copy, verbose = verbose)
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1      90000    2          2         2   34      0      0      0      0
# 2      50000    2          2         1   37      0      0      0      0
# 3      50000    1          2         1   57     -1      0     -1      0
# 4      50000    1          1         2   37      0      0      0      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1      0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 2      0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 3      0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
# 4      0  ...    19394.0    19619.0    20024.0    2500.0    1815.0     657.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %%
load_dataset.shape

# %%
data = load_dataset.sample(frac=0.95, random_state=786)
data_unseen = load_dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (22800, 24)
# Unseen Data For Predictions: (1200, 24)

# %%
from pycaret.classification import setup, compare_models,get_metrics,models,create_model

# %%
exp_clf101 = setup(data = data, target = 'default',train_size=0.7,silent=True,session_id=123)
# Out:
# <style type="text/css">
# #T_e8584_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e8584">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8584_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e8584_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8584_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8584_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e8584_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e8584_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8584_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e8584_row1_col1" class="data row1 col1" >default</td>
#     </tr>
#     <tr>
#       <th id="T_e8584_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_e6efe th {
#   text-align: left;
# }
# ...

# %%
dt = create_model('dt',return_train_score=False)
# Out:
# <style type="text/css">
# #T_63b0c_row10_col0, #T_63b0c_row10_col1, #T_63b0c_row10_col2, #T_63b0c_row10_col3, #T_63b0c_row10_col4, #T_63b0c_row10_col5, #T_63b0c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_63b0c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63b0c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_63b0c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_63b0c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_63b0c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_63b0c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_63b0c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_63b0c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Split</th>
# ...

# %%
print(dt)
